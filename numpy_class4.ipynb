# %% [markdown]
# ##Fancy Indexing
# you can Pick elements from specific positions using a list/array of indices.

# %%
import numpy as np
arr = np.array([10,20,30,40,50,60])

arr [[1,3]]
# Out:
# array([20, 40])

# %% [markdown]
# You can do this fancy indexing in 2D Matrix aswell

# %%
matrix = np.arange(1,13).reshape(3,4)
matrix
matrix[[0,2],[1,2]]
# Out:
# array([ 2, 11])

# %% [markdown]
# ##Conditional Selection
# Find values based on conditions or replace them.

# %%
arr =np.array([1,2,3,4,5,11,17])

np.where(arr > 10,arr,0)
# Out:
# array([ 0,  0,  0,  0,  0, 11, 17])

# %% [markdown]
# ##Sorting & Ordering
# np.sort() → returns sorted array
#
# np.argsort() → returns indices of sorted order

# %%
arr =np.array([22,43,54,34])
np.sort(arr)
# Out:
# array([22, 34, 43, 54])

# %%
arr =np.array([22,43,54,34])
np.argsort(arr)
# Out:
# array([0, 3, 1, 2])

# %% [markdown]
# ##Concatenation & Stacking

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

np.concat([a,b])
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# Vertical & Horizontal Stacking

# %%
a = np.array([[1,2,3],[4,5,6]])
b = np.array([[11,12,13],[14,15,16]])

np.vstack((a,b))
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [11, 12, 13],
#        [14, 15, 16]])

# %%
np.hstack((a,b))
# Out:
# array([[ 1,  2,  3, 11, 12, 13],
#        [ 4,  5,  6, 14, 15, 16]])

# %%
np.concat([a,b])
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [11, 12, 13],
#        [14, 15, 16]])
